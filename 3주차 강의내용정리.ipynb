# %% [markdown]
# # 텍스트 마이닝의 이론과 실제

# %% [markdown]
# ## 텍스트 마이닝 이란?
# - Turn unstructured text into structured data,
#     - 일정한 길이 (sparse or dense) 의 vector로 변환
# - and use the structured data in various tasks such as
#     - text classification, clustering, sentiment analysis, document summarization, translation, prediction, etc.
#     - 변환된 vector에 머신러닝 (딥러닝) 기법을 적용

# %% [markdown]
# ## 텍스트 마이닝 방법
# - NLP(Natural Language Processing) 기본도구
#     - Tokenize, stemming, lemmatize
#     - Chunking
#     - BOW, TFIDF – sparse representation
# - 머신러닝(딥러닝)
#     - Naïve Bayes, Logistic egression, Decision tree, SVM
#     - Embedding(Word2Vec, Doc2Vec) – dense representation
#     - RNN(LSTM), Attention, Transformer

# %% [markdown]
# ## 텍스트 마이닝 단계
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 텍스트 마이닝 적용분야
# - Document classification
#     - Sentiment analysis, classification
# - Document generation
#     - Q&A, summarization, translation
# - Keyword extraction
#     - tagging/annotation
# - Topic modeling
#     - LSA(Latent Semantic Analysis), LDA(Latent Dirichlet Allocation)

# %% [markdown]
# # 텍스트 마이닝 기본도구
# - 목적: document, sentence 등을 sparse vector로 변환
# - Tokenize
#     - 대상이 되는 문서/문장을 최소 단위로 쪼갬
# - Text normalization
#     - 최소 단위를 표준화
# - POS-tagging
#     - 최소 의미단위로 나누어진 대상에 대해 품사를 부착
# - Chunking
#     - POS-tagging의 결과를 명사구, 형용사구, 분사구 등과 같은 말모듬으로 다시 합치는 과정
# - BOW, TFIDF <-- 팀 발표에서 실제로 진행해보았다.
#     - tokenized 결과를 이용하여 문서를 vector로 표현

# %% [markdown]
# # 기본기법 중 하나를 설명하겠다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 위 그림은 팀 발표에 사용된 TF/IDF 예제이다. 여기서 TF =  1/한 영화의 장류 분류수 이고
#
# IDF = LOG10(전체영화편수/해당장르 출현수)

# %% [markdown]
# 이에 따른 코사인 유사도는 다음과 같다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 나이브 베이즈 분류
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 한글감성분석
# 한글 감성분석 예제는 필자의 깃허브에 네이버 영화리뷰 감성분석한 코드가 있다.
#
# 다음과 같이 딥러닝 기법을 이용하여 긍정/부정 리뷰를 해준것을 알 수 있다.
# 하지만 기법의 큰 결함이 있다. 바로 모호한 발언의 리뷰는 잡아내지 못한다.
# 지금 이 밑에 있는 것은 성공사례만을 캡처한 것이지만
# 예를 들어 영화 <곡성>의 가장 많은 좋아요를 받은
# " 관객에게 미끼를 던진 영화" 라는 리뷰는 긍정리뷰이지만 97% 확률로 부정리뷰로 판별하였다..
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 주성분 분석
# ![image.png](attachment:image.png)
